# %%
eficiencia = dados.groupby("canal")["ROI"].mean().sort_values(ascending=False)
print("\n Canal mais eficiente em ROI:")
display(eficiencia)
# Out:
#  Canal mais eficiente em ROI:
# canal
# Email        0.000646
# WhatsApp     0.000528
# Instagram    0.000385
# Facebook     0.000000
# Rádio        0.000000
# SMS          0.000000
# TV           0.000000
# Name: ROI, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=dados, x="publico_alvo", y="taxa_resposta")
plt.title("Distribuição da Taxa de Resposta por Público")
plt.ylabel("Taxa de Resposta (%)")
plt.xlabel("Público-alvo")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=dados, x="canal", y="taxa_resposta", errorbar=None)
plt.title("Taxa Média de Resposta por Canal")
plt.ylabel("Taxa de Resposta (%)")
plt.xlabel("Canal de Marketing")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", palette="muted")

dados = pd.read_csv("../data/campanhas.csv")

print("Primeiras linhas do dataset:")
display(dados.head())

print("\n Informações do dataset:")
print(dados.info())

print("\n Estatísticas descritivas:")
display(dados.describe())
# Out:
# Primeiras linhas do dataset:
#    id_campanha      canal    publico_alvo  taxa_resposta  custo  sucesso
# 0            1      Email  Jovens Adultos           22.5   1500        1
# 1            2  Instagram  Jovens Adultos           34.2   2500        1
# 2            3        SMS         Adultos            9.4    800        0
# 3            4   Facebook          Idosos           12.1   1200        0
# 4            5   WhatsApp  Jovens Adultos           40.8   2000        1
#  Informações do dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id_campanha    10 non-null     int64
#  1   canal          10 non-null     object
#  2   publico_alvo   10 non-null     object
#  3   taxa_resposta  10 non-null     float64
#  4   custo          10 non-null     int64
#  5   sucesso        10 non-null     int64
# ...
